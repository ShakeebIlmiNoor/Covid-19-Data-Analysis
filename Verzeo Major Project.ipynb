# %% [markdown]
# # MAJOR PROJECT

# %% [markdown]
# ## Importing Dataset

# %%
# Importing pandas for performing operations on dataset
import pandas as pd

# Importing dataset which is in the form of a CSV File
dataset = pd.read_csv("owid-covid-data.csv")

# %%
# Printing first 10 rows
dataset.head(10)
# Out:
#   iso_code      continent location        date  total_cases  new_cases  \
# 0      ABW  North America    Aruba  13-03-2020          2.0        2.0
# 1      ABW  North America    Aruba  20-03-2020          4.0        2.0
# 2      ABW  North America    Aruba  24-03-2020         12.0        8.0
# 3      ABW  North America    Aruba  25-03-2020         17.0        5.0
# 4      ABW  North America    Aruba  26-03-2020         19.0        2.0
# 5      ABW  North America    Aruba  27-03-2020         28.0        9.0
# 6      ABW  North America    Aruba  28-03-2020         28.0        0.0
# 7      ABW  North America    Aruba  29-03-2020         28.0        0.0
# 8      ABW  North America    Aruba  30-03-2020         50.0       22.0
# 9      ABW  North America    Aruba  01-04-2020         55.0        5.0
#
#    total_deaths  new_deaths  total_cases_per_million  new_cases_per_million  \
# 0           0.0         0.0                   18.733                 18.733
# ...

# %% [markdown]
# ## Subsetting those rows which have India in their location

# %%
data_ind = dataset[dataset["location"]=='India']

# %%
# Getting dimensions of the new dataset
data_ind.shape
# Out:
# (219, 36)

# %%
# Re-indexing the Dataset
data_ind.index=list(range(1,220))

# Finding information of null values in Dataset
data_ind.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 219 entries, 1 to 219
# Data columns (total 36 columns):
# iso_code                           219 non-null object
# continent                          219 non-null object
# location                           219 non-null object
# date                               219 non-null object
# total_cases                        219 non-null float64
# new_cases                          219 non-null float64
# total_deaths                       219 non-null float64
# new_deaths                         219 non-null float64
# total_cases_per_million            219 non-null float64
# new_cases_per_million              219 non-null float64
# total_deaths_per_million           219 non-null float64
# new_deaths_per_million             219 non-null float64
# new_tests                          129 non-null float64
# total_tests                        135 non-null float64
# total_tests_per_thousand           135 non-null float64
# ...

# %% [markdown]
# ## Handling Missing Values

# %%
# Filling the null values of continuous numeric with the mean of the column
data_ind.fillna(data_ind.mean(),inplace=True)

# Filling the null values of the categorical column with the mode of the column
data_ind['tests_units'].fillna("samples tested", inplace = True)

# Finding information of the null values in the Dataset
data_ind.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 219 entries, 1 to 219
# Data columns (total 36 columns):
# iso_code                           219 non-null object
# continent                          219 non-null object
# location                           219 non-null object
# date                               219 non-null object
# total_cases                        219 non-null float64
# new_cases                          219 non-null float64
# total_deaths                       219 non-null float64
# new_deaths                         219 non-null float64
# total_cases_per_million            219 non-null float64
# new_cases_per_million              219 non-null float64
# total_deaths_per_million           219 non-null float64
# new_deaths_per_million             219 non-null float64
# new_tests                          219 non-null float64
# total_tests                        219 non-null float64
# total_tests_per_thousand           219 non-null float64
# ...

# %% [markdown]
# ## Univariate Analysis

# %%
# Importing libraries for Visual Representation of Data
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Histograms

# %%
sns.set()
plt.hist(data_ind['new_cases'], color='darkgrey', edgecolor='dimgrey', linewidth=1)
plt.title('Plot showing New Cases')
plt.xlabel('New Cases')
plt.ylabel('Frequency')
plt.show()

# %%
sns.set()
plt.hist(data_ind['new_deaths'], color='lightcoral', edgecolor='indianred', linewidth=1)
plt.title('Plot showing New Deaths')
plt.xlabel('New Deaths')
plt.ylabel('Frequency')
plt.show()

# %%
sns.set()
plt.hist(data_ind['total_cases'], bins = 4, color='coral', edgecolor='red', linewidth=1)
plt.title('Plot showing Number of Total Cases')
plt.xlabel('Total Cases')
plt.ylabel('Frequency')
plt.xticks([500000, 1000000, 1500000, 2000000])
plt.show()

# %%
sns.set()
plt.hist(data_ind['new_tests'], color='sandybrown', edgecolor='peru', linewidth=1)
plt.title('Plot showing New Tests')
plt.xlabel('Number of New Tests per day')
plt.ylabel('Frequency')
plt.show()

# %%
sns.set()
plt.hist(data_ind['total_deaths'], color='bisque', edgecolor='burlywood', linewidth=1)
plt.title('Plot showing Number of Total Deaths')
plt.xlabel('Number of total deaths per day')
plt.ylabel('Frequency')
plt.show()

# %%
sns.set()
plt.hist(data_ind['total_tests'], color='goldenrod', edgecolor='darkgoldenrod', linewidth=1)
plt.title('Plot showing Total Tests')
plt.xlabel('Number of total tests per day (in ten millions)')
plt.ylabel('Frequency')
#plt.xticks([2,4,6,8,10,12,14,16])
plt.show()

# %%
sns.set()
plt.hist(data_ind['new_tests_smoothed'], color='lemonchiffon', edgecolor='khaki', linewidth=1)
plt.title('Plot showing New Tests Smoothed')
plt.xlabel('Number of new tests smoothed per day')
plt.ylabel('Frequency')
plt.show()

# %%
sns.set()
plt.hist(data_ind['tests_per_case'], color='greenyellow', edgecolor='yellowgreen', linewidth=1)
plt.title('Plot showing Tests per Case')
plt.xlabel('Number of tests per case')
plt.ylabel('Frequency')
plt.show()

# %%
sns.set()
plt.hist(data_ind['positive_rate'], color='palegreen', edgecolor='limegreen', linewidth=1)
plt.title('Plot showing Positive Rate')
plt.xlabel('Positive rate per day')
plt.ylabel('Frequency')
plt.show()

# %%
sns.set()
plt.hist(data_ind['stringency_index'], color='aquamarine', edgecolor='mediumaquamarine', linewidth=1)
plt.title('Plot showing Stringency Index')
plt.xlabel('Stringency Index per day')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ### Printing Mean, Median and Mode of each column of the Dataset

# %%
# Prints Mean
print(data_ind.mean())
# Out:
# total_cases                        2.585647e+05
# new_cases                          8.970484e+03
# total_deaths                       6.610406e+03
# new_deaths                         1.858402e+02
# total_cases_per_million            1.873651e+02
# new_cases_per_million              6.500324e+00
# total_deaths_per_million           4.790137e+00
# new_deaths_per_million             1.346575e-01
# new_tests                          1.706548e+05
# total_tests                        5.831065e+06
# total_tests_per_thousand           4.225422e+00
# new_tests_per_thousand             1.236822e-01
# new_tests_smoothed                 1.455537e+05
# new_tests_smoothed_per_thousand    1.054714e-01
# tests_per_case                     1.824934e+01
# positive_rate                      6.577857e-02
# stringency_index                   5.686171e+01
# population                         1.380004e+09
# population_density                 4.504190e+02
# median_age                         2.820000e+01
# ...

# %%
# Prints Median
print(data_ind.median())
# Out:
# total_cases                        1.571200e+04
# new_cases                          1.334000e+03
# total_deaths                       5.070000e+02
# new_deaths                         3.800000e+01
# total_cases_per_million            1.138500e+01
# new_cases_per_million              9.670000e-01
# total_deaths_per_million           3.670000e-01
# new_deaths_per_million             2.800000e-02
# new_tests                          1.706548e+05
# total_tests                        5.831065e+06
# total_tests_per_thousand           4.225422e+00
# new_tests_per_thousand             1.236822e-01
# new_tests_smoothed                 1.455537e+05
# new_tests_smoothed_per_thousand    1.054714e-01
# tests_per_case                     1.824934e+01
# positive_rate                      6.577857e-02
# stringency_index                   7.546000e+01
# population                         1.380004e+09
# population_density                 4.504190e+02
# median_age                         2.820000e+01
# ...

# %%
# Prints Mode
print(data_ind.mode().transpose()[0])
# Out:
# iso_code                                      IND
# continent                                    Asia
# location                                    India
# date                                   01-01-2020
# total_cases                                     0
# new_cases                                       0
# total_deaths                                    0
# new_deaths                                      0
# total_cases_per_million                         0
# new_cases_per_million                           0
# total_deaths_per_million                        0
# new_deaths_per_million                          0
# new_tests                                  170655
# total_tests                           5.83107e+06
# total_tests_per_thousand                  4.22542
# new_tests_per_thousand                   0.123682
# new_tests_smoothed                         145554
# new_tests_smoothed_per_thousand          0.105471
# tests_per_case                            18.2493
# ...

# %% [markdown]
# ## Bivariate Analysis

# %% [markdown]
# ### Scatter Plots

# %%
sns.set()
plt.scatter(data_ind['new_deaths'].values, data_ind['total_cases'].values, s = 20, c = 'mediumpurple')
plt.xlabel('Number of New Deaths')
plt.ylabel('Number of Total Cases')
plt.title('Total Cases Vs New Deaths')
plt.margins(0.02)
plt.show()

# %%
sns.set()
plt.scatter(data_ind['total_deaths'].values, data_ind['total_cases'].values, s = 20, c = 'rosybrown')
plt.xlabel('Number of Total Deaths')
plt.ylabel('Number of Total Cases')
plt.title('Total Cases Vs Total Deaths')
plt.margins(0.02)
plt.show()

# %%
sns.set()
plt.scatter(data_ind['new_tests'].values, data_ind['total_cases'].values, s = 20, c = 'fuchsia')
plt.xlabel('Number of New Tests')
plt.ylabel('Number of Total Cases')
plt.title('Total Cases Vs New Tests')
plt.margins(0.02)
plt.show()

# %%
sns.set()
plt.scatter(data_ind['total_tests'].values, data_ind['total_cases'].values, s = 20, c='lightcoral')
plt.xlabel('Number of Total Tests')
plt.ylabel('Number of Total Cases')
plt.title('Total Cases Vs Total Tests')
plt.margins(0.02)
plt.show()

# %%
sns.set()
plt.scatter(data_ind['tests_per_case'].values, data_ind['total_cases'].values, s = 20, c = 'darkturquoise')
plt.xlabel('Tests per Case')
plt.ylabel('Number of Total Cases')
plt.title('Total Cases Vs Tests per Case')
plt.margins(0.02)
plt.show()

# %%
sns.set()
plt.scatter(data_ind['new_tests_smoothed'].values, data_ind['total_cases'].values, s = 20, c = 'mediumspringgreen')
plt.xlabel('New Tests Smoothed')
plt.ylabel('Number of Total Cases')
plt.title('Total Cases Vs New Tests Smoothed')
plt.margins(0.02)
plt.show()

# %%
sns.set()
plt.scatter(data_ind['stringency_index'].values, data_ind['total_cases'].values, s = 20, c = 'yellowgreen')
plt.xlabel('Stringency Index')
plt.ylabel('Number of Total Cases')
plt.title('Total Cases Vs Stringency Index')
plt.margins(0.02)
plt.show()

# %%
sns.set()
plt.scatter(data_ind['positive_rate'].values, data_ind['total_cases'].values, s = 20, c = 'darkkhaki')
plt.xlabel('Positive Rate')
plt.ylabel('Number of Total Cases')
plt.title('Total Cases Vs Positive Rate')
plt.margins(0.02)
plt.show()

# %%
sns.set()
plt.scatter(data_ind['gdp_per_capita'].values, data_ind['total_cases'].values, s = 20, c = 'orchid')
plt.xlabel('GDP per Capita')
plt.ylabel('Number of Total Cases')
plt.title('Total Cases Vs GDP per Capita')
plt.margins(0.02)
plt.show()

# %%
sns.set()
plt.scatter(data_ind['life_expectancy'].values, data_ind['total_cases'].values, c = 'peru')
plt.xlabel('Life Expectancy')
plt.ylabel('Number of Total Cases')
plt.title('Total Cases Vs Life Expectancy')
plt.margins(0.02)
plt.show()

# %% [markdown]
# ### Line Plots

# %%
sns.set()
plt.plot(data_ind['new_deaths'].values, data_ind['total_cases'].values)
plt.xlabel('Number of New Deaths')
plt.ylabel('Number of Total Cases')
plt.title('Total Cases Vs New Deaths')
plt.margins(0.02)
plt.show()

# %%
sns.set()
plt.plot(data_ind['total_deaths'].values, data_ind['total_cases'].values)
plt.xlabel('Number of Total Deaths')
plt.ylabel('Number of Total Cases')
plt.title('Total Cases Vs Tota Deaths')
plt.margins(0.02)
plt.show()

# %%
sns.set()
plt.plot(data_ind['new_tests'].values, data_ind['total_cases'].values, c = 'fuchsia')
plt.xlabel('Number of New Tests')
plt.ylabel('Number of Total Cases')
plt.title('Total Cases Vs New Tests')
plt.margins(0.02)
plt.show()

# %%
sns.set()
plt.plot(data_ind['total_tests'].values, data_ind['total_cases'].values, c='lightcoral')
plt.xlabel('Number of Total Tests')
plt.ylabel('Number of Total Cases')
plt.title('Total Cases Vs Total Tests')
plt.margins(0.02)
plt.show()

# %%
sns.set()
plt.plot(data_ind['tests_per_case'].values, data_ind['total_cases'].values, c = 'darkturquoise')
plt.xlabel('Tests per Case')
plt.ylabel('Number of Total Cases')
plt.title('Total Cases Vs Tests per Case')
plt.margins(0.02)
plt.show()

# %%
sns.set()
plt.plot(data_ind['new_tests_smoothed'].values, data_ind['total_cases'].values, c = 'mediumspringgreen')
plt.xlabel('New Tests Smoothed')
plt.ylabel('Number of Total Cases')
plt.title('Total Cases Vs New Tests Smoothed')
plt.margins(0.02)
plt.show()

# %%
sns.set()
plt.plot(data_ind['stringency_index'].values, data_ind['total_cases'].values, c = 'yellowgreen')
plt.xlabel('Stringency Index')
plt.ylabel('Number of Total Cases')
plt.title('Total Cases Vs Stringency Index')
plt.margins(0.02)
plt.show()

# %%
sns.set()
plt.plot(data_ind['positive_rate'].values, data_ind['total_cases'].values, c = 'darkkhaki')
plt.xlabel('Positive Rate')
plt.ylabel('Number of Total Cases')
plt.title('Total Cases Vs Positive Rate')
plt.margins(0.02)
plt.show()

# %%
sns.set()
plt.plot(data_ind['gdp_per_capita'].values, data_ind['total_cases'].values, c = 'orchid')
plt.xlabel('GDP per Capita')
plt.ylabel('Number of Total Cases')
plt.title('Total Cases Vs GDP per Capita')
plt.margins(0.02)
plt.show()

# %%
sns.set()
plt.plot(data_ind['life_expectancy'].values, data_ind['total_cases'].values, c = 'peru')
plt.xlabel('Life Expectancy')
plt.ylabel('Number of Total Cases')
plt.title('Total Cases Vs Life Expectancy')
plt.margins(0.02)
plt.show()

# %% [markdown]
# ## Converting Date Column to Ordinal

# %%
# Importing datetime and converting date column to ordinal form
import datetime as dt
data_ind.loc[:,'date'] = pd.to_datetime(data_ind['date'])
data_ind.loc[:,'date'] = data_ind['date'].map(dt.datetime.toordinal)
# Out:
# C:\Users\Md Ilmul Hoda\Anaconda3\lib\site-packages\pandas\core\indexing.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s

# %% [markdown]
# ## Dropping Useless Categorical Columns

# %%
# Dropping all columns which are useless for modelling purposes
useful_dat = data_ind.drop(['iso_code','continent','location','tests_units'], axis = 1)

# %%
useful_dat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 219 entries, 1 to 219
# Data columns (total 32 columns):
# date                               219 non-null int64
# total_cases                        219 non-null float64
# new_cases                          219 non-null float64
# total_deaths                       219 non-null float64
# new_deaths                         219 non-null float64
# total_cases_per_million            219 non-null float64
# new_cases_per_million              219 non-null float64
# total_deaths_per_million           219 non-null float64
# new_deaths_per_million             219 non-null float64
# new_tests                          219 non-null float64
# total_tests                        219 non-null float64
# total_tests_per_thousand           219 non-null float64
# new_tests_per_thousand             219 non-null float64
# new_tests_smoothed                 219 non-null float64
# new_tests_smoothed_per_thousand    219 non-null float64
# ...

# %% [markdown]
# ## Selecting "total_cases" Column as Target Column

# %%
y = useful_dat['total_cases']

# %% [markdown]
# ## Selecting Other Columns as Features

# %%
X = useful_dat.drop('total_cases', axis = 1)

# %% [markdown]
# ## Performing Train-Test Split

# %%
# Implementing Train-test split
from sklearn.model_selection import train_test_split
# We perform hyperparameter tuning during Train-test split and choose the optimum values to provide maximum accuracy
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.30, random_state = 64)

# %% [markdown]
# ## Data Modelling

# %% [markdown]
# ### Implementing Linear Regression

# %%
from sklearn.linear_model import LinearRegression
# Instantiation
linreg = LinearRegression()

# Fitting the model
linreg.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %% [markdown]
# ### Printing Accuracy of Linear Regression Model

# %%
accuracy = linreg.score(X_test, y_test) * 100
print("Accuracy of the model while using Linear Regression is " + str(accuracy) + " %")
# Out:
# Accuracy of the model while using Linear Regression is 99.99999999994984 %

# %% [markdown]
# ### Implementing Random Forest Regressor

# %%
from sklearn.ensemble import RandomForestRegressor
# Instantiation
random = RandomForestRegressor()

# Fitting the model
random.fit(X_train, y_train)
# Out:
# C:\Users\Md Ilmul Hoda\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#                       max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=10,
#                       n_jobs=None, oob_score=False, random_state=None,
#                       verbose=0, warm_start=False)

# %% [markdown]
# ### Printing Accuracy of Random Forest Regressor

# %%
accuracy = random.score(X_test, y_test) * 100
print("Accuracy of the model while using Random Forest Regressor is " + str(accuracy) + " %")
# Out:
# Accuracy of the model while using Random Forest Regressor is 99.71762241118678 %

# %% [markdown]
# ## Now, Time To Predict !!!

# %%
# I have created a CSV File using mean values of all the columns except for the Date column
# We have to predict the total number of cases on a given date
# Importing the File
predict_dat = pd.read_csv('predict.csv')

# %%
predict_dat
# Out:
#          date  new_cases  total_deaths  new_deaths  total_cases_per_million  \
# 0  10-08-2020       8970          6610         185                      187
#
#    new_cases_per_million  total_deaths_per_million  new_deaths_per_million  \
# 0                6.50032                  4.790137                0.134658
#
#    new_tests  total_tests  ...  aged_70_older  gdp_per_capita  \
# 0     170654      5831065  ...          3.414         6426.67
#
#    extreme_poverty  cardiovasc_death_rate  diabetes_prevalence  \
# 0             21.2                 282.28                10.39
#
#    female_smokers  male_smokers  handwashing_facilities  \
# 0             1.9          20.6                   59.55
#
#    hospital_beds_per_thousand  life_expectancy
# 0                        0.53            69.66
#
# [1 rows x 31 columns]

# %%
# Changing the Date column to Ordinal Form
predict_dat.loc[:,'date'] = pd.to_datetime(predict_dat['date'])
predict_dat.loc[:,'date'] = predict_dat['date'].map(dt.datetime.toordinal)

# %%
# Prediction of total cases given by Linear Regression Algorithm
print((int)(linreg.predict(predict_dat)[0]))
# Out:
# 258060

# %%
# Prediction of total cases given by Random Forest Algorithm
print((int)(random.predict(predict_dat)[0]))
# Out:
# 226835
